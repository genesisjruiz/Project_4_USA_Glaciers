# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm,skew
from scipy import stats
from sklearn.neighbors import KDTree
# %matplotlib inline
from sklearn.cluster import KMeans
from sklearn.linear_model import LinearRegression,Ridge,RidgeCV, ElasticNetCV, LassoCV,BayesianRidge
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler,StandardScaler,MinMaxScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split, GridSearchCV
from sklearn import linear_model
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from pykml import parser
#Import randomforest functions
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
import warnings
warnings.filterwarnings("ignore")

# %%
import plotly
import plotly.express as px
import plotly.graph_objects as go 
import psycopg2
import pandas as pd
import matplotlib as plt
import seaborn as sns
from functools import reduce

# Establish a connection to the PostgreSQL database
conn = psycopg2.connect(
    dbname="glacier",
    user="postgres",
    password="postgres",
    host="localhost",
    port="5433"
)

# %%
# Write your SQL query
query = 'SELECT * FROM public."glacier_data";'

# Execute the query and load the results into a DataFrame
clustered_df = pd.read_sql_query(query, conn)

# Print the DataFrame
clustered_df.head()
# Out:
#   line_type anlys_time src_date  db_area min_elev mean_elev max_elev  \
# 0         2      13269    10804  495.176        0         0        0
# 1         2      13726    11522   297.56        0         0        0
# 2         2      13269    10804  162.882        0         0        0
# 3         2      13269    10804  495.176        0         0        0
# 4         2      13269    10804  495.176        0         0        0
#
#   prime_class rec_status  release_dt glac_stat        geog_area conn_lvl  \
# 0           4       okay  1177210698         1  Various (NSIDC)        0
# 1           5       okay  1192067393         1  Various (NSIDC)        0
# 2           5       okay  1150232094         1  Various (NSIDC)        0
# 3           4       okay  1177210698         1  Various (NSIDC)        0
# 4           4       okay  1177210698         1  Various (NSIDC)        0
#
#   surge_type term_type gtng_o1reg gtng_o2reg rgi_gl_typ cluster  Value
# 0          0         9          1          6          0      24  46.77
# 1          0         9          1          5          0      67  55.43
# 2          0         9          1          6          0      38  46.77
# 3          0         9          1          6          0      24  46.77
# 4          0         9          1          6          0      24  46.77

# %%
categorical_df = clustered_df[['rec_status','geog_area']]

# %%
categorical_df.head()
# Out:
#   rec_status        geog_area
# 0       okay  Various (NSIDC)
# 1       okay  Various (NSIDC)
# 2       okay  Various (NSIDC)
# 3       okay  Various (NSIDC)
# 4       okay  Various (NSIDC)

# %%
numerical_df = clustered_df.drop(columns=['rec_status','geog_area','conn_lvl'])

# %%
numerical_df['surge_type'].value_counts()
# Out:
# surge_type
# 0    69119
# 3      280
# 2      150
# 1       23
# Name: count, dtype: int64

# %%
numerical_df.head()
# Out:
#   line_type anlys_time src_date  db_area min_elev mean_elev max_elev  \
# 0         2      13269    10804  495.176        0         0        0
# 1         2      13726    11522   297.56        0         0        0
# 2         2      13269    10804  162.882        0         0        0
# 3         2      13269    10804  495.176        0         0        0
# 4         2      13269    10804  495.176        0         0        0
#
#   prime_class  release_dt glac_stat surge_type term_type gtng_o1reg  \
# 0           4  1177210698         1          0         9          1
# 1           5  1192067393         1          0         9          1
# 2           5  1150232094         1          0         9          1
# 3           4  1177210698         1          0         9          1
# 4           4  1177210698         1          0         9          1
#
#   gtng_o2reg rgi_gl_typ cluster  Value
# 0          6          0      24  46.77
# 1          5          0      67  55.43
# 2          6          0      38  46.77
# 3          6          0      24  46.77
# 4          6          0      24  46.77

# %%
clustered_df['line_type'].value_counts()
# Out:
# line_type
# 3    55560
# 2    14009
# 1        3
# Name: count, dtype: int64

# %%
#Trying dummies
dummies = pd.get_dummies(categorical_df)
dummies
# Out:
#        rec_status_okay  geog_area_Alaska  geog_area_Chugach  \
# 0                 True             False              False
# 1                 True             False              False
# 2                 True             False              False
# 3                 True             False              False
# 4                 True             False              False
# ...                ...               ...                ...
# 69567             True             False              False
# 69568             True             False              False
# 69569             True             False              False
# 69570             True             False              False
# 69571             True             False              False
#
#        geog_area_Conterminous USA  geog_area_Juneau area  \
# 0                           False                  False
# 1                           False                  False
# 2                           False                  False
# 3                           False                  False
# 4                           False                  False
# ...                           ...                    ...
# 69567                        True                  False
# 69568                        True                  False
# 69569                        True                  False
# 69570                        True                  False
# 69571                        True                  False
#
#        geog_area_Kenai Peninsula  geog_area_Northern Cordillera  \
# 0                          False                          False
# 1                          False                          False
# 2                          False                          False
# 3                          False                          False
# 4                          False                          False
# ...                          ...                            ...
# 69567                      False                          False
# 69568                      False                          False
# 69569                      False                          False
# 69570                      False                          False
# 69571                      False                          False
#
#        geog_area_Olympic Peninsula  geog_area_Prince William Sound  \
# 0                            False                           False
# 1                            False                           False
# 2                            False                           False
# 3                            False                           False
# 4                            False                           False
# ...                            ...                             ...
# 69567                        False                           False
# 69568                        False                           False
# 69569                        False                           False
# 69570                        False                           False
# 69571                        False                           False
#
#        geog_area_Randolph Glacier Inventory; Umbrella RC for merging the RGI into GLIMS  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 69567                                              False
# 69568                                              False
# 69569                                              False
# 69570                                              False
# 69571                                              False
#
#        geog_area_Various (GlobGlacier)  geog_area_Various (NSIDC)
# 0                                False                       True
# 1                                False                       True
# 2                                False                       True
# 3                                False                       True
# 4                                False                       True
# ...                                ...                        ...
# 69567                            False                      False
# 69568                            False                      False
# 69569                            False                      False
# 69570                            False                      False
# 69571                            False                      False
#
# [69572 rows x 12 columns]

# %%
to_train_df = pd.concat([numerical_df,dummies],axis=1)

# %%
to_train_df.head()
# Out:
#   line_type anlys_time src_date  db_area min_elev mean_elev max_elev  \
# 0         2      13269    10804  495.176        0         0        0
# 1         2      13726    11522   297.56        0         0        0
# 2         2      13269    10804  162.882        0         0        0
# 3         2      13269    10804  495.176        0         0        0
# 4         2      13269    10804  495.176        0         0        0
#
#   prime_class  release_dt glac_stat  ... geog_area_Chugach  \
# 0           4  1177210698         1  ...             False
# 1           5  1192067393         1  ...             False
# 2           5  1150232094         1  ...             False
# 3           4  1177210698         1  ...             False
# 4           4  1177210698         1  ...             False
#
#   geog_area_Conterminous USA geog_area_Juneau area geog_area_Kenai Peninsula  \
# 0                      False                 False                     False
# 1                      False                 False                     False
# 2                      False                 False                     False
# 3                      False                 False                     False
# 4                      False                 False                     False
#
#   geog_area_Northern Cordillera geog_area_Olympic Peninsula  \
# 0                         False                       False
# 1                         False                       False
# 2                         False                       False
# 3                         False                       False
# 4                         False                       False
#
#   geog_area_Prince William Sound  \
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
#
#    geog_area_Randolph Glacier Inventory; Umbrella RC for merging the RGI into GLIMS  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    geog_area_Various (GlobGlacier)  geog_area_Various (NSIDC)
# 0                            False                       True
# 1                            False                       True
# 2                            False                       True
# 3                            False                       True
# 4                            False                       True
#
# [5 rows x 29 columns]

# %%
#Assign variables to X and Y for classification 
y = to_train_df['glac_stat']
X = to_train_df.drop(columns='glac_stat')

# %%
#Random Forest Classifier
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1, stratify=y)
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.9986776289311792

# %%
predictions = clf.predict(X_test)

# %%
training_matrix = confusion_matrix(y_test,predictions)
training_matrix_df = pd.DataFrame(training_matrix, index = ['Actual Non-Existent Glaciers', 'Actual Existent Glaciers'],
                                columns=['Predicted Non-Existent Glaciers','Predicted Existent Glaciers'])
training_matrix_df
# Out:
#                               Predicted Non-Existent Glaciers  \
# Actual Non-Existent Glaciers                                1
# Actual Existent Glaciers                                    6
#
#                               Predicted Existent Glaciers
# Actual Non-Existent Glaciers                           17
# Actual Existent Glaciers                            17369

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.14      0.06      0.08        18
#            1       1.00      1.00      1.00     17375
#
#     accuracy                           1.00     17393
#    macro avg       0.57      0.53      0.54     17393
# weighted avg       1.00      1.00      1.00     17393

# %%
r_squared = r2_score(y_test,predictions)

# %%
print(r_squared)
# Out:
# -0.27910151878497214

# %%
#Trying seaborn display for confusion matrix, not sure if it looks good
# Get and reshape confusion matrix data
training_matrix = training_matrix.astype('float') / training_matrix.sum(axis=1)[:, np.newaxis]

# Build the plot
#plt.figure(figsize=(16,7))
sns.set(font_scale=1.4)
sns.heatmap(training_matrix, annot=True, annot_kws={'size':10},
            cmap=plt.cm.Blues, linewidths=0.2)

# Add labels to the plot
class_names = ['Non-existent','Existent']
tick_marks = np.arange(len(class_names))
tick_marks2 = tick_marks + 0.5
plt.xticks(tick_marks, class_names, rotation=25)
plt.yticks(tick_marks2, class_names, rotation=0)
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix for Random Forest Model')
plt.show()
